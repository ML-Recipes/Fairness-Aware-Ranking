# %%
import elasticsearch
import pandas as pd

# %%
boston_df = pd.read_csv('../data/Boston/listings.csv')

# %%
boston_df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   3781   https://www.airbnb.com/rooms/3781  20201221044328   2020-12-21
# 1   6695   https://www.airbnb.com/rooms/6695  20201221044328   2020-12-21
# 2  10813  https://www.airbnb.com/rooms/10813  20201221044328   2020-12-21
# 3  10986  https://www.airbnb.com/rooms/10986  20201221044328   2020-12-21
# 4  13247  https://www.airbnb.com/rooms/13247  20201221044328   2020-12-21
#
#                                                 name  \
# 0                          HARBORSIDE-Walk to subway
# 1                     $99 Special!! Home Away! Condo
# 2  Back Bay Apt-blocks to subway, Newbury St, The...
# 3  North End (Waterfront area)  CLOSE TO MGH & SU...
# 4                          Back Bay studio apartment
#
#                                          description  \
# 0  Fully separate apartment in a two apartment bu...
# 1  Comfortable,  Fully Equipped private apartment...
# 2  Stunning Back Bay furnished studio apartment. ...
# 3  Chic furnished studio apartment is located on ...
# 4  Beautiful studio apartment in a great Back Bay...
#
#                                neighborhood_overview  \
# 0  Mostly quiet ( no loud music, no crowed sidewa...
# 1  Peaceful, Architecturally interesting, histori...
# 2  Wander around this quintessential neighborhood...
# 3                                                NaN
# 4  The Back Bay has so many great shops & restaur...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/24670/b2de044...     4804
# 1  https://a0.muscache.com/pictures/38ac4797-e7a4...     8229
# 2  https://a0.muscache.com/pictures/20b5b9c9-e1f4...    38997
# 3  https://a0.muscache.com/pictures/46994/567b606...    38997
# 4  https://a0.muscache.com/pictures/miso/Hosting-...    51637
#
#                                   host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/4804  ...                        10.0
# 1   https://www.airbnb.com/users/show/8229  ...                        10.0
# 2  https://www.airbnb.com/users/show/38997  ...                        10.0
# 3  https://www.airbnb.com/users/show/38997  ...                         NaN
# 4  https://www.airbnb.com/users/show/51637  ...                         NaN
#
#   review_scores_location review_scores_value     license instant_bookable  \
# 0                   10.0                10.0         NaN                f
# 1                    9.0                10.0  STR-404620                f
# 2                   10.0                10.0         NaN                f
# 3                    NaN                 NaN         NaN                f
# 4                    NaN                 NaN         NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              4                                           4
# 2                             11                                          11
# 3                             11                                          11
# 4                              2                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.26
# 1                                           0              0.83
# 2                                           0              0.85
# 3                                           0              0.04
# 4                                           0               NaN
#
# [5 rows x 74 columns]

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3106 entries, 0 to 3105
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3106 non-null   int64
#  1   listing_url                                   3106 non-null   object
#  2   scrape_id                                     3106 non-null   int64
#  3   last_scraped                                  3106 non-null   object
#  4   name                                          3106 non-null   object
#  5   description                                   3073 non-null   object
#  6   neighborhood_overview                         2195 non-null   object
#  7   picture_url                                   3106 non-null   object
#  8   host_id                                       3106 non-null   int64
#  9   host_url                                      3106 non-null   object
#  10  host_name                                     3106 non-null   object
#  11  host_since                                    3106 non-null   object
#  12  host_location                                 3102 non-null   object
#  13  host_about                                    2098 non-null   object
#  14  host_response_time                            2338 non-null   object
#  15  host_response_rate                            2338 non-null   object
#  16  host_acceptance_rate                          2571 non-null   object
#  17  host_is_superhost                             3106 non-null   object
#  18  host_thumbnail_url                            3106 non-null   object
#  19  host_picture_url                              3106 non-null   object
#  20  host_neighbourhood                            2919 non-null   object
#  21  host_listings_count                           3106 non-null   int64
#  22  host_total_listings_count                     3106 non-null   int64
#  23  host_verifications                            3106 non-null   object
#  24  host_has_profile_pic                          3106 non-null   object
#  25  host_identity_verified                        3106 non-null   object
#  26  neighbourhood                                 2195 non-null   object
#  27  neighbourhood_cleansed                        3106 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      3106 non-null   float64
#  30  longitude                                     3106 non-null   float64
#  31  property_type                                 3106 non-null   object
#  32  room_type                                     3106 non-null   object
#  33  accommodates                                  3106 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                3102 non-null   object
#  36  bedrooms                                      2748 non-null   float64
#  37  beds                                          3082 non-null   float64
#  38  amenities                                     3106 non-null   object
#  39  price                                         3106 non-null   object
#  40  minimum_nights                                3106 non-null   int64
#  41  maximum_nights                                3106 non-null   int64
#  42  minimum_minimum_nights                        3105 non-null   float64
#  43  maximum_minimum_nights                        3105 non-null   float64
#  44  minimum_maximum_nights                        3105 non-null   float64
#  45  maximum_maximum_nights                        3105 non-null   float64
#  46  minimum_nights_avg_ntm                        3105 non-null   float64
#  47  maximum_nights_avg_ntm                        3105 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              3106 non-null   object
#  50  availability_30                               3106 non-null   int64
#  51  availability_60                               3106 non-null   int64
#  52  availability_90                               3106 non-null   int64
#  53  availability_365                              3106 non-null   int64
#  54  calendar_last_scraped                         3106 non-null   object
#  55  number_of_reviews                             3106 non-null   int64
#  56  number_of_reviews_ltm                         3106 non-null   int64
#  57  number_of_reviews_l30d                        3106 non-null   int64
#  58  first_review                                  2229 non-null   object
#  59  last_review                                   2229 non-null   object
#  60  review_scores_rating                          2213 non-null   float64
#  61  review_scores_accuracy                        2211 non-null   float64
#  62  review_scores_cleanliness                     2212 non-null   float64
#  63  review_scores_checkin                         2210 non-null   float64
#  64  review_scores_communication                   2213 non-null   float64
#  65  review_scores_location                        2211 non-null   float64
#  66  review_scores_value                           2211 non-null   float64
#  67  license                                       1645 non-null   object
#  68  instant_bookable                              3106 non-null   object
#  69  calculated_host_listings_count                3106 non-null   int64
#  70  calculated_host_listings_count_entire_homes   3106 non-null   int64
#  71  calculated_host_listings_count_private_rooms  3106 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   3106 non-null   int64
#  73  reviews_per_month                             2229 non-null   float64
# dtypes: float64(21), int64(19), object(34)
# memory usage: 1.8+ MB

# %%
print(boston_df.iloc[0])
# Out:
# id                                                                           3781
# listing_url                                     https://www.airbnb.com/rooms/3781
# scrape_id                                                          20201221044328
# last_scraped                                                           2020-12-21
# name                                                    HARBORSIDE-Walk to subway
#                                                               ...
# calculated_host_listings_count                                                  1
# calculated_host_listings_count_entire_homes                                     1
# calculated_host_listings_count_private_rooms                                    0
# calculated_host_listings_count_shared_rooms                                     0
# reviews_per_month                                                            0.26
# Name: 0, Length: 74, dtype: object

# %%
pd.set_option('display.max_rows', 500)

# %%
boston_df.iloc[1]
# Out:
# id                                                                                           6695
# listing_url                                                     https://www.airbnb.com/rooms/6695
# scrape_id                                                                          20201221044328
# last_scraped                                                                           2020-12-21
# name                                                               $99 Special!! Home Away! Condo
# description                                     Comfortable,  Fully Equipped private apartment...
# neighborhood_overview                           Peaceful, Architecturally interesting, histori...
# picture_url                                     https://a0.muscache.com/pictures/38ac4797-e7a4...
# host_id                                                                                      8229
# host_url                                                   https://www.airbnb.com/users/show/8229
# host_name                                                                                   Terry
# host_since                                                                             2009-02-19
# host_location                                                Boston, Massachusetts, United States
# host_about                                                  Relaxed,  Easy going, Accommodating.
# host_response_time                                                                            NaN
# host_response_rate                                                                            NaN
# host_acceptance_rate                                                                         100%
# host_is_superhost                                                                               t
# host_thumbnail_url                              https://a0.muscache.com/im/users/8229/profile_...
# host_picture_url                                https://a0.muscache.com/im/users/8229/profile_...
# host_neighbourhood                                                                        Roxbury
# host_listings_count                                                                             4
# host_total_listings_count                                                                       4
# host_verifications                                           ['email', 'phone', 'reviews', 'kba']
# host_has_profile_pic                                                                            t
# host_identity_verified                                                                          t
# neighbourhood                                                Boston, Massachusetts, United States
# neighbourhood_cleansed                                                                    Roxbury
# neighbourhood_group_cleansed                                                                  NaN
# latitude                                                                                  42.3299
# longitude                                                                                -71.0935
# property_type                                                                  Entire condominium
# room_type                                                                         Entire home/apt
# accommodates                                                                                    4
# bathrooms                                                                                     NaN
# bathrooms_text                                                                             1 bath
# bedrooms                                                                                        1
# beds                                                                                            1
# amenities                                       ["Cable TV", "Hangers", "Wifi", "Free street p...
# price                                                                                     $169.00
# minimum_nights                                                                                  3
# maximum_nights                                                                                730
# minimum_minimum_nights                                                                          3
# maximum_minimum_nights                                                                          3
# minimum_maximum_nights                                                                        730
# maximum_maximum_nights                                                                        730
# minimum_nights_avg_ntm                                                                          3
# maximum_nights_avg_ntm                                                                        730
# calendar_updated                                                                              NaN
# has_availability                                                                                t
# availability_30                                                                                 0
# availability_60                                                                                 0
# availability_90                                                                                 0
# availability_365                                                                                0
# calendar_last_scraped                                                                  2020-12-21
# number_of_reviews                                                                             115
# number_of_reviews_ltm                                                                           0
# number_of_reviews_l30d                                                                          0
# first_review                                                                           2009-08-06
# last_review                                                                            2019-11-02
# review_scores_rating                                                                           96
# review_scores_accuracy                                                                         10
# review_scores_cleanliness                                                                      10
# review_scores_checkin                                                                          10
# review_scores_communication                                                                    10
# review_scores_location                                                                          9
# review_scores_value                                                                            10
# license                                                                                STR-404620
# instant_bookable                                                                                f
# calculated_host_listings_count                                                                  4
# calculated_host_listings_count_entire_homes                                                     4
# calculated_host_listings_count_private_rooms                                                    0
# calculated_host_listings_count_shared_rooms                                                     0
# reviews_per_month                                                                            0.83
# Name: 1, dtype: object

# %%
boston_df.iloc[2]
# Out:
# id                                                                                          10813
# listing_url                                                    https://www.airbnb.com/rooms/10813
# scrape_id                                                                          20201221044328
# last_scraped                                                                           2020-12-21
# name                                            Back Bay Apt-blocks to subway, Newbury St, The...
# description                                     Stunning Back Bay furnished studio apartment. ...
# neighborhood_overview                           Wander around this quintessential neighborhood...
# picture_url                                     https://a0.muscache.com/pictures/20b5b9c9-e1f4...
# host_id                                                                                     38997
# host_url                                                  https://www.airbnb.com/users/show/38997
# host_name                                                                                Michelle
# host_since                                                                             2009-09-16
# host_location                                                                                  US
# host_about                                                                                    NaN
# host_response_time                                                                 within an hour
# host_response_rate                                                                            94%
# host_acceptance_rate                                                                           8%
# host_is_superhost                                                                               f
# host_thumbnail_url                              https://a0.muscache.com/im/pictures/user/13444...
# host_picture_url                                https://a0.muscache.com/im/pictures/user/13444...
# host_neighbourhood                                                                       Back Bay
# host_listings_count                                                                            15
# host_total_listings_count                                                                      15
# host_verifications                              ['email', 'phone', 'reviews', 'jumio', 'offlin...
# host_has_profile_pic                                                                            t
# host_identity_verified                                                                          t
# neighbourhood                                                Boston, Massachusetts, United States
# neighbourhood_cleansed                                                                   Back Bay
# neighbourhood_group_cleansed                                                                  NaN
# latitude                                                                                  42.3506
# longitude                                                                                -71.0879
# property_type                                                                    Entire apartment
# room_type                                                                         Entire home/apt
# accommodates                                                                                    3
# bathrooms                                                                                     NaN
# bathrooms_text                                                                             1 bath
# bedrooms                                                                                      NaN
# beds                                                                                            1
# amenities                                       ["Cable TV", "Hangers", "Wifi", "Kitchen", "Fi...
# price                                                                                      $70.00
# minimum_nights                                                                                 28
# maximum_nights                                                                               1125
# minimum_minimum_nights                                                                         28
# maximum_minimum_nights                                                                         28
# minimum_maximum_nights                                                                       1125
# maximum_maximum_nights                                                                       1125
# minimum_nights_avg_ntm                                                                         28
# maximum_nights_avg_ntm                                                                       1125
# calendar_updated                                                                              NaN
# has_availability                                                                                t
# availability_30                                                                                 0
# availability_60                                                                                 0
# availability_90                                                                                 0
# availability_365                                                                                0
# calendar_last_scraped                                                                  2020-12-21
# number_of_reviews                                                                              10
# number_of_reviews_ltm                                                                          10
# number_of_reviews_l30d                                                                          3
# first_review                                                                           2020-01-04
# last_review                                                                            2020-12-05
# review_scores_rating                                                                           99
# review_scores_accuracy                                                                         10
# review_scores_cleanliness                                                                      10
# review_scores_checkin                                                                          10
# review_scores_communication                                                                    10
# review_scores_location                                                                         10
# review_scores_value                                                                            10
# license                                                                                       NaN
# instant_bookable                                                                                f
# calculated_host_listings_count                                                                 11
# calculated_host_listings_count_entire_homes                                                    11
# calculated_host_listings_count_private_rooms                                                    0
# calculated_host_listings_count_shared_rooms                                                     0
# reviews_per_month                                                                            0.85
# Name: 2, dtype: object

# %%
boston_df.iloc[1].host_since
# Out:
# '2009-02-19'

# %%
boston_df.iloc[1].host_about
# Out:
# 'Relaxed,  Easy going, Accommodating. '

# %%
boston_df.iloc[2].host_neighbourhood
# Out:
# 'Back Bay'

# %%
boston_df.iloc[1].host_about
# Out:
# 'Relaxed,  Easy going, Accommodating. '

# %%
geneva_df = pd.read_csv('../data/Geneva/listings.csv')

# %%
geneva_df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   42515   https://www.airbnb.com/rooms/42515  20201229152854   2020-12-30
# 1   44959   https://www.airbnb.com/rooms/44959  20201229152854   2020-12-30
# 2  107438  https://www.airbnb.com/rooms/107438  20201229152854   2020-12-30
# 3  194110  https://www.airbnb.com/rooms/194110  20201229152854   2020-12-30
# 4  256797  https://www.airbnb.com/rooms/256797  20201229152854   2020-12-30
#
#                                              name  \
# 0                 Geneva center - Hosting females
# 1  Perfect Cozy Bedroom Close to Lake & Transport
# 2             Room in an amazingflat linked to UN
# 3                   Central apartment by the lake
# 4               Charming apartment in city center
#
#                                          description  \
# 0  <b>The space</b><br />This is a private room w...
# 1  Perfect for the single traveler whether it be ...
# 2  <b>The space</b><br />Version Française et Ang...
# 3  Design apartment conveniently located in the h...
# 4  <b>The space</b><br />My apartment is ideally ...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  The apartment is situated in the heart of Gene...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/10640277/ff1d...   185647
# 1  https://a0.muscache.com/pictures/3340619/139f4...   198343
# 2  https://a0.muscache.com/pictures/2032232/48301...   556499
# 3  https://a0.muscache.com/pictures/1252014/0ee91...   942248
# 4  https://a0.muscache.com/pictures/2661715/ee3fb...  1350910
#
#                                     host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/185647  ...                        10.0
# 1   https://www.airbnb.com/users/show/198343  ...                        10.0
# 2   https://www.airbnb.com/users/show/556499  ...                        10.0
# 3   https://www.airbnb.com/users/show/942248  ...                         9.0
# 4  https://www.airbnb.com/users/show/1350910  ...                        10.0
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   10.0                 9.0     NaN                f
# 1                    9.0                 9.0     NaN                f
# 2                    9.0                 9.0     NaN                f
# 3                   10.0                 9.0     NaN                f
# 4                    9.0                 9.0     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           0
# 1                              1                                           0
# 2                              2                                           1
# 3                              1                                           1
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.51
# 1                                           0              0.39
# 2                                           0              0.23
# 3                                           0              0.66
# 4                                           0              0.26
#
# [5 rows x 74 columns]

# %%
hk_df = pd.read_csv('../data/HK/listings.csv')

# %%
hk_df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   69074   https://www.airbnb.com/rooms/69074  20201222152003   2020-12-23
# 1   75083   https://www.airbnb.com/rooms/75083  20201222152003   2020-12-22
# 2  103760  https://www.airbnb.com/rooms/103760  20201222152003   2020-12-22
# 3  104626  https://www.airbnb.com/rooms/104626  20201222152003   2020-12-22
# 4  132773  https://www.airbnb.com/rooms/132773  20201222152003   2020-12-23
#
#                                               name  \
# 0  Beautiful oasis of plants & art @ best location
# 1                      SoHo off Hollywood Road  3B
# 2    Central Centre 5 min walk to/from Central MTR
# 3              Entire Flat - Next to Man Mo Temple
# 4                Fabulous 2 Bdrm Aprt Open kitchen
#
#                                          description  \
# 0  An ideal Hong location any visitor--hip withou...
# 1  Located steps from Hollywood road, with new ea...
# 2  Located right in the heart of Central, this 2 ...
# 3  <b>The space</b><br />Situated in one of Hong ...
# 4  Nicely decorated, spacious 2 bedroom apartment...
#
#                                neighborhood_overview  \
# 0  In the upper part of trendy, hip Sheung Wan, w...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The Sheung Wan neighbourhood is ever changing ...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/84364564/1e0c...   160139
# 1  https://a0.muscache.com/pictures/2873745/90c15...   304876
# 2  https://a0.muscache.com/pictures/815221/056993...   304876
# 3  https://a0.muscache.com/pictures/1947265/ef01a...   544166
# 4  https://a0.muscache.com/pictures/36936441/e4c1...   304876
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/160139  ...                        10.0
# 1  https://www.airbnb.com/users/show/304876  ...                         9.0
# 2  https://www.airbnb.com/users/show/304876  ...                        10.0
# 3  https://www.airbnb.com/users/show/544166  ...                        10.0
# 4  https://www.airbnb.com/users/show/304876  ...                        10.0
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   10.0                 9.0     NaN                f
# 1                   10.0                 9.0     NaN                f
# 2                   10.0                 9.0     NaN                f
# 3                   10.0                 9.0     NaN                f
# 4                   10.0                10.0     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                             14                                          10
# 2                             14                                          10
# 3                              1                                           1
# 4                             14                                          10
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            4
# 2                                            4
# 3                                            0
# 4                                            4
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.12
# 1                                           0              1.92
# 2                                           0              2.35
# 3                                           0              0.12
# 4                                           0              3.05
#
# [5 rows x 74 columns]

# %%
hk_df.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'number_of_reviews_l30d',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'license',
#  'instant_bookable',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
hk_df.host_location.iloc[0]
# Out:
# 'Hong Kong'

# %%
# merge all datasets into one
df = pd.concat([
    boston_df, geneva_df, hk_df
])

# %%
boston_df.shape
# Out:
# (3106, 74)

# %%
geneva_df.shape
# Out:
# (2043, 74)

# %%
hk_df.shape
# Out:
# (7047, 74)

# %%
df.shape
# Out:
# (12196, 74)

# %%
df.to_csv('../data/dataset.csv', index=False)

# %%
from elasticsearch import Elasticsearch
from tqdm import tqdm

es = Elasticsearch([{'host':'localhost','port':9200}], http_auth=('username', 'password'))

# %%
def index_data(data, index_name):
    
    # create index if not exist
    if es.indices.exists(index_name):
        es.indices.create(index=index_name)
    
    i = 0
    for index, row in data.iterrows():
        i += 1
        data = {
            'id': row['id'],
             'listing_url': row['listing_url'],
             'scrape_id': row['scrape_id'],
             'last_scraped': row['last_scraped'],
             'name': row['name'],
             'description': row['description'],
             'neighborhood_overview': row['neighborhood_overview'],
             'picture_url': row['picture_url'],
             'host_id': row['host_id'],
             'host_url': row['host_url'],
             'host_name': row['host_name'],
             'host_since': row['host_since'],
             'host_location': row['host_location'],
             'host_about': row['host_about'],
             'host_response_time': row['host_response_time']
        }
        #print('data: ', data)
        #if i == 1:
        #    break

# %%
index_data(df, 'asdad')
# Out:
# data:  {'id': 3781, 'listing_url': 'https://www.airbnb.com/rooms/3781', 'scrape_id': 20201221044328, 'last_scraped': '2020-12-21', 'name': 'HARBORSIDE-Walk to subway', 'description': 'Fully separate apartment in a two apartment building. Space is perfect for an individual or a couple. There is a full bath, bedroom with queen bed, small sitting area with TV and a fully equipped kitchen with dining area. Walk or bus to subway.<br /><br /><b>The space</b><br />This is a totally separate apartment located on the first floor of a 3 story building. Apartment has one bedroom with queen sized bed plus full eat-in kitchen,sitting room and full bath with tub/shower. Free off street parking for one car. SORRY NO SNOW REMOVAL SERVICE FOR CAR.  Free wi-fi <br /><br />10 minute walk/5 minute bus (3 doors away) to subway station--next stop is Aquarium/Faneuil Hall in central Boston. <br /><br />Guests who have stayed in our apartment have used it as a home base to explore Boston and surroundings. Others during extended stays at the apartment have commuted to  Massachusetts General Hospital (MGH) and Massachusetts Institute of Technology (MIT).  <br /><br />The harbor and harbor wa', 'neighborhood_overview': 'Mostly quiet ( no loud music, no crowed sidewalks)  area with residential 3 story buildings, some 4 and 5 story newer buildings. Though not in an "entertainment" area there are local food shops and supermarket with a mix of restaurants.  Area is in transition--East Boston has a great waterfront with gentrification evident everywhere!', 'picture_url': 'https://a0.muscache.com/pictures/24670/b2de0442_original.jpg', 'host_id': 4804, 'host_url': 'https://www.airbnb.com/users/show/4804', 'host_name': 'Frank', 'host_since': '2008-12-03', 'host_location': 'Massachusetts', 'host_about': 'My wife and I and grown children frequently occupy the spaces that we rent and as such try to make the spaces pleasant and appealing to ourselves as well as guests.   We have been subletting for over 15 years and consider ourselves helpful and organized hosts who provide clean, attractive and comfortable apartments', 'host_response_time': 'within a day'}

# %%
def index_data(data, index_name):
    
    # create index if not exist
    if es.indices.exists(index_name):
        es.indices.create(index=index_name)
    
    i = 0
    for index, row in data.iterrows():
        i += 1
        data = {
            'id': row['id'],
             'listing_url': row['listing_url'],
             'scrape_id': row['scrape_id'],
             'last_scraped': row['last_scraped'],
             'name': row['name'],
             'description': row['description'],
             'neighborhood_overview': row['neighborhood_overview'],
             'picture_url': row['picture_url'],
             'host_id': row['host_id'],
             'host_url': row['host_url'],
             'host_name': row['host_name'],
             'host_since': row['host_since'],
             'host_location': row['host_location'],
             'host_about': row['host_about'],
             'host_response_time': row['host_response_time'],
             'host_response_rate': row['host_response_rate'],
             'host_acceptance_rate': row['host_acceptance_rate'],
             'host_is_superhost': row['host_is_superhost'],
             'host_thumbnail_url': row['host_thumbnail_url'],
             'host_picture_url': row['host_picture_url'],
             'host_neighbourhood': row['host_neighbourhood'],
             'host_listings_count': row['host_listings_count'],
             'host_total_listings_count': row['host_total_listings_count'],
             'host_verifications': row['host_verifications'],
             'host_has_profile_pic': row['host_has_profile_pic'],
             'host_identity_verified': row['host_identity_verified'],
             'neighbourhood': row['neighbourhood'],
             'neighbourhood_cleansed': row['neighbourhood_cleansed'],
             'neighbourhood_group_cleansed': row['neighbourhood_group_cleansed'],
             'latitude': row['latitude'],
             'longitude': row['longitude'],
             'property_type': row['property_type'],
             'room_type': row['room_type'],
             'accommodates': row['accommodates'],
             'bathrooms': row['bathrooms'],
             'bathrooms_text': row['bathrooms_text'],
             'bedrooms': row['bedrooms'],
             'beds': row['beds'],
             'amenities': row['amenities'],
             'price': row['price'],
             'minimum_nights': row['minimum_nights'],
             'maximum_nights': row['maximum_nights'],
             'minimum_minimum_nights': row['minimum_minimum_nights'],
             'maximum_minimum_nights': row['maximum_minimum_nights'],
             'minimum_maximum_nights': row['minimum_maximum_nights'],
             'maximum_maximum_nights': row['maximum_maximum_nights'],
             'minimum_nights_avg_ntm': row['minimum_nights_avg_ntm'],
             'maximum_nights_avg_ntm': row['maximum_nights_avg_ntm'],
             'calendar_updated': row['calendar_updated'],
             'has_availability': row['has_availability'],
             'availability_30': row['availability_30'],
             'availability_60': row['availability_60'],
             'availability_90': row['availability_90'],
             'availability_365': row['availability_365'],
             'calendar_last_scraped': row['calendar_last_scraped'],
             'number_of_reviews': row['number_of_reviews'],
             'number_of_reviews_ltm': row['number_of_reviews_ltm'],
             'number_of_reviews_l30d': row['number_of_reviews_l30d'],
             'first_review': row['first_review'],
             'last_review': row['last_review'],
             'review_scores_rating': row['review_scores_rating'],
             'review_scores_accuracy': row['review_scores_accuracy'],
             'review_scores_cleanliness': row['review_scores_cleanliness'],
             'review_scores_checkin': row['review_scores_checkin'],
             'review_scores_communication': row['review_scores_communication'],
             'review_scores_location': row['review_scores_location'],
             'review_scores_value': row['review_scores_value'],
             'license': row['license'],
             'instant_bookable': row['instant_bookable'],
             'calculated_host_listings_count': row['calculated_host_listings_count'],
             'calculated_host_listings_count_entire_homes': row['calculated_host_listings_count_entire_homes'],
             'calculated_host_listings_count_private_rooms': row['calculated_host_listings_count_private_rooms'],
             'calculated_host_listings_count_shared_rooms': row['calculated_host_listings_count_shared_rooms'],
             'reviews_per_month': row['reviews_per_month']
            
        }
        
        print('data: ', data)
        res=es.index(index=index_name,doc_type='doc',body=data)
        
        if i == 1:
            break
            
            
    
index_data(df, 'asdad')
# Out:
# data:  {'id': 3781, 'listing_url': 'https://www.airbnb.com/rooms/3781', 'scrape_id': 20201221044328, 'last_scraped': '2020-12-21', 'name': 'HARBORSIDE-Walk to subway', 'description': 'Fully separate apartment in a two apartment building. Space is perfect for an individual or a couple. There is a full bath, bedroom with queen bed, small sitting area with TV and a fully equipped kitchen with dining area. Walk or bus to subway.<br /><br /><b>The space</b><br />This is a totally separate apartment located on the first floor of a 3 story building. Apartment has one bedroom with queen sized bed plus full eat-in kitchen,sitting room and full bath with tub/shower. Free off street parking for one car. SORRY NO SNOW REMOVAL SERVICE FOR CAR.  Free wi-fi <br /><br />10 minute walk/5 minute bus (3 doors away) to subway station--next stop is Aquarium/Faneuil Hall in central Boston. <br /><br />Guests who have stayed in our apartment have used it as a home base to explore Boston and surroundings. Others during extended stays at the apartment have commuted to  Massachusetts General Hospital (MGH) and Massachusetts Institute of Technology (MIT).  <br /><br />The harbor and harbor wa', 'neighborhood_overview': 'Mostly quiet ( no loud music, no crowed sidewalks)  area with residential 3 story buildings, some 4 and 5 story newer buildings. Though not in an "entertainment" area there are local food shops and supermarket with a mix of restaurants.  Area is in transition--East Boston has a great waterfront with gentrification evident everywhere!', 'picture_url': 'https://a0.muscache.com/pictures/24670/b2de0442_original.jpg', 'host_id': 4804, 'host_url': 'https://www.airbnb.com/users/show/4804', 'host_name': 'Frank', 'host_since': '2008-12-03', 'host_location': 'Massachusetts', 'host_about': 'My wife and I and grown children frequently occupy the spaces that we rent and as such try to make the spaces pleasant and appealing to ourselves as well as guests.   We have been subletting for over 15 years and consider ourselves helpful and organized hosts who provide clean, attractive and comfortable apartments', 'host_response_time': 'within a day', 'host_response_rate': '100%', 'host_acceptance_rate': '31%', 'host_is_superhost': 'f', 'host_thumbnail_url': 'https://a0.muscache.com/im/users/4804/profile_pic/1327953150/original.jpg?aki_policy=profile_small', 'host_picture_url': 'https://a0.muscache.com/im/users/4804/profile_pic/1327953150/original.jpg?aki_policy=profile_x_medium', 'host_neighbourhood': 'East Boston', 'host_listings_count': 5, 'host_total_listings_count': 5, 'host_verifications': "['email', 'phone', 'reviews']", 'host_has_profile_pic': 't', 'host_identity_verified': 'f', 'neighbourhood': 'Boston, Massachusetts, United States', 'neighbourhood_cleansed': 'East Boston', 'neighbourhood_group_cleansed': nan, 'latitude': 42.364129999999996, 'longitude': -71.02991, 'property_type': 'Entire apartment', 'room_type': 'Entire home/apt', 'accommodates': 2, 'bathrooms': nan, 'bathrooms_text': '1 bath', 'bedrooms': 1.0, 'beds': 0.0, 'amenities': '["Cable TV", "Hangers", "Wifi", "Free street parking", "Kitchen", "Patio or balcony", "Carbon monoxide alarm", "Dishes and silverware", "Essentials", "Heating", "Cooking basics", "Extra pillows and blankets", "Free parking on premises", "Microwave", "Smoke alarm", "TV", "Dishwasher", "Coffee maker", "Shampoo", "Iron", "Oven", "Hot water", "Washer", "Stove", "Refrigerator", "Hair dryer", "Dedicated workspace", "Bed linens", "Air conditioning", "Dryer"]', 'price': '$132.00', 'minimum_nights': 28, 'maximum_nights': 1125, 'minimum_minimum_nights': 28.0, 'maximum_minimum_nights': 28.0, 'minimum_maximum_nights': 1125.0, 'maximum_maximum_nights': 1125.0, 'minimum_nights_avg_ntm': 28.0, 'maximum_nights_avg_ntm': 1125.0, 'calendar_updated': nan, 'has_availability': 't', 'availability_30': 29, 'availability_60': 59, 'availability_90': 89, 'availability_365': 253, 'calendar_last_scraped': '2020-12-21', 'number_of_reviews': 17 ...
# /usr/local/lib/python3.8/site-packages/elasticsearch/connection/base.py:177: ElasticsearchDeprecationWarning: [types removal] Specifying types in document index requests is deprecated, use the typeless endpoints instead (/{index}/_doc/{id}, /{index}/_doc, or /{index}/_create/{id}).
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)
# ---------------------------------------------------------------------------
# RequestError                              Traceback (most recent call last)
# <ipython-input-28-ba0ad804e420> in <module>
#      94
#      95
# ---> 96 index_data(df, 'asdad')
#
# <ipython-input-28-ba0ad804e420> in index_data(data, index_name)
#      87
#      88         print('data: ', data)
# ---> 89         res=es.index(index=index_name,doc_type='doc',body=data)
#      90
#      91         if i == 1:
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     137                 if p in kwargs:
#     138                     params[p] = kwargs.pop(p)
# --> 139             return func(*args, params=params, headers=headers, **kwargs)
#     140
#     141         return _wrapped
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/client/__init__.py in index(self, index, body, doc_type, id, params, headers)
#     373             doc_type = "_doc"
#     374
# --> 375         return self.transport.perform_request(
#     376             "POST" if id in SKIP_IN_PATH else "PUT",
#     377             _make_path(index, doc_type, id),
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     343
#     344             try:
# --> 345                 status, headers_response, data = connection.perform_request(
#     346                     method,
#     347                     url,
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     254                 method, full_url, url, orig_body, duration, response.status, raw_data
#     255             )
# --> 256             self._raise_error(response.status, raw_data)
#     257
#     258         self.log_request_success(
#
# /usr/local/lib/python3.8/site-packages/elasticsearch/connection/base.py in _raise_error(self, status_code, raw_data)
#     285             logger.warning("Undecodable raw error response from server: %s", err)
#     286
# --> 287         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
#     288             status_code, error_message, additional_info
#     289         )
#
# RequestError: RequestError(400, 'mapper_parsing_exception', 'failed to parse')
