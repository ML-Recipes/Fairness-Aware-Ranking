# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('../data/Airbnb/Boston/listings.csv')

# %%
# check first 5 occurences
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   3781   https://www.airbnb.com/rooms/3781  20201221044328   2020-12-21
# 1   6695   https://www.airbnb.com/rooms/6695  20201221044328   2020-12-21
# 2  10813  https://www.airbnb.com/rooms/10813  20201221044328   2020-12-21
# 3  10986  https://www.airbnb.com/rooms/10986  20201221044328   2020-12-21
# 4  13247  https://www.airbnb.com/rooms/13247  20201221044328   2020-12-21
#
#                                                 name  \
# 0                          HARBORSIDE-Walk to subway
# 1                     $99 Special!! Home Away! Condo
# 2  Back Bay Apt-blocks to subway, Newbury St, The...
# 3  North End (Waterfront area)  CLOSE TO MGH & SU...
# 4                          Back Bay studio apartment
#
#                                          description  \
# 0  Fully separate apartment in a two apartment bu...
# 1  Comfortable,  Fully Equipped private apartment...
# ...

# %%
# check datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3106 entries, 0 to 3105
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3106 non-null   int64
#  1   listing_url                                   3106 non-null   object
#  2   scrape_id                                     3106 non-null   int64
#  3   last_scraped                                  3106 non-null   object
#  4   name                                          3106 non-null   object
#  5   description                                   3073 non-null   object
#  6   neighborhood_overview                         2195 non-null   object
#  7   picture_url                                   3106 non-null   object
#  8   host_id                                       3106 non-null   int64
# ...

# %%
# check total number of records and columns
df.shape
# Out:
# (3106, 74)

# %%
# column feature names
df.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
# ...

# %%
# sample record
print(df.iloc[0])
# Out:
# id                                                                                           3781
# listing_url                                                     https://www.airbnb.com/rooms/3781
# scrape_id                                                                          20201221044328
# last_scraped                                                                           2020-12-21
# name                                                                    HARBORSIDE-Walk to subway
# description                                     Fully separate apartment in a two apartment bu...
# neighborhood_overview                           Mostly quiet ( no loud music, no crowed sidewa...
# picture_url                                     https://a0.muscache.com/pictures/24670/b2de044...
# host_id                                                                                      4804
# host_url                                                   https://www.airbnb.com/users/show/4804
# ...

# %%
df.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               0
# description                                       33
# neighborhood_overview                            911
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                      4
# host_about                                      1008
# host_response_time                               768
# host_response_rate                               768
# host_acceptance_rate                             535
# host_is_superhost                                  0
# ...

# %%
clean_df = df[df.first_review.notnull() & df.last_review.notnull() & df.review_scores_rating.notnull() & df.review_scores_accuracy.notnull() & df.review_scores_accuracy.notnull() & df.review_scores_cleanliness.notnull() & df.review_scores_checkin.notnull() & df.review_scores_communication.notnull() & df.review_scores_location.notnull() & df.review_scores_value.notnull()]

# %%
clean_df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   3781   https://www.airbnb.com/rooms/3781  20201221044328   2020-12-21
# 1   6695   https://www.airbnb.com/rooms/6695  20201221044328   2020-12-21
# 2  10813  https://www.airbnb.com/rooms/10813  20201221044328   2020-12-21
# 6  18711  https://www.airbnb.com/rooms/18711  20201221044328   2020-12-21
# 7  22195  https://www.airbnb.com/rooms/22195  20201221044328   2020-12-21
#
#                                                 name  \
# 0                          HARBORSIDE-Walk to subway
# 1                     $99 Special!! Home Away! Condo
# 2  Back Bay Apt-blocks to subway, Newbury St, The...
# 6  The Dorset Redline | 3BR 1BA | Walk to Redline...
# 7                      Copley House - Premium Studio
#
#                                          description  \
# 0  Fully separate apartment in a two apartment bu...
# 1  Comfortable,  Fully Equipped private apartment...
# ...

# %%
clean_df.shape
# Out:
# (2210, 74)

# %%
clean_df.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               0
# description                                        9
# neighborhood_overview                            479
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                      2
# host_about                                       638
# host_response_time                               603
# host_response_rate                               603
# host_acceptance_rate                             368
# host_is_superhost                                  0
# ...

# %%
clean_df.drop(['bathrooms'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# fill NaN with "" for string values
clean_df[['listing_url', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_url', 'host_name', 
    'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 
    'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_has_profile_pic', 
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 
    'property_type', 'room_type', 'bathrooms_text', 'price', 'license', 'calendar_updated', 'first_review', 
    'last_review']] = clean_df[['listing_url', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_url', 
    'host_name', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 
    'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_has_profile_pic', 
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 
    'property_type', 'room_type', 'bathrooms_text', 'price', 'license', 'calendar_updated', 'first_review', 
 'last_review']].fillna(value="")
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py:3062: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# fill NaN with 0.0 for float values
clean_df[['latitude', 'longitude', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 
    'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 
    'reviews_per_month']] = clean_df[['latitude', 'longitude', 'review_scores_rating', 'review_scores_accuracy', 
    'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 
    'review_scores_value', 'reviews_per_month']].fillna(value=0.0)

# %%
# fill NaN with 0 for integer values
clean_df[['minimum_nights', 'maximum_nights', 'maximum_minimum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 
    'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 
    'maximum_nights_avg_ntm', 'bathrooms', 'beds']] = clean_df[['minimum_nights', 'maximum_nights', 'maximum_minimum_nights', 
    'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 
    'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'bedrooms', 'beds']].fillna(value=0)

# %%
clean_df.to_csv('../data/Airbnb/Boston/clean_listings.csv', index=False)
