# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('../data/Airbnb/Hong_Kong/listings.csv')

# %%
# check first 5 occurences
df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   69074   https://www.airbnb.com/rooms/69074  20201222152003   2020-12-23
# 1   75083   https://www.airbnb.com/rooms/75083  20201222152003   2020-12-22
# 2  103760  https://www.airbnb.com/rooms/103760  20201222152003   2020-12-22
# 3  104626  https://www.airbnb.com/rooms/104626  20201222152003   2020-12-22
# 4  132773  https://www.airbnb.com/rooms/132773  20201222152003   2020-12-23
#
#                                               name  \
# 0  Beautiful oasis of plants & art @ best location
# 1                      SoHo off Hollywood Road  3B
# 2    Central Centre 5 min walk to/from Central MTR
# 3              Entire Flat - Next to Man Mo Temple
# 4                Fabulous 2 Bdrm Aprt Open kitchen
#
#                                          description  \
# 0  An ideal Hong location any visitor--hip withou...
# 1  Located steps from Hollywood road, with new ea...
# 2  Located right in the heart of Central, this 2 ...
# 3  <b>The space</b><br />Situated in one of Hong ...
# 4  Nicely decorated, spacious 2 bedroom apartment...
#
#                                neighborhood_overview  \
# 0  In the upper part of trendy, hip Sheung Wan, w...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The Sheung Wan neighbourhood is ever changing ...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/84364564/1e0c...   160139
# 1  https://a0.muscache.com/pictures/2873745/90c15...   304876
# 2  https://a0.muscache.com/pictures/815221/056993...   304876
# 3  https://a0.muscache.com/pictures/1947265/ef01a...   544166
# 4  https://a0.muscache.com/pictures/36936441/e4c1...   304876
#
#                                    host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/160139       Amy  2010-07-07
# 1  https://www.airbnb.com/users/show/304876     Brend  2010-11-30
# 2  https://www.airbnb.com/users/show/304876     Brend  2010-11-30
# 3  https://www.airbnb.com/users/show/544166    Celine  2011-04-29
# 4  https://www.airbnb.com/users/show/304876     Brend  2010-11-30
#
#                  host_location  \
# 0                    Hong Kong
# 1                    Hong Kong
# 2                    Hong Kong
# 3  Hong Kong Island, Hong Kong
# 4                    Hong Kong
#
#                                           host_about  host_response_time  \
# 0  I've been with AirBnB now for many years, ofte...        within a day
# 1  I was born in California and raised in Hong Ko...  within a few hours
# 2  I was born in California and raised in Hong Ko...  within a few hours
# 3  i am Celine Heuls.\r\ni live in Hong KOng Isla...  a few days or more
# 4  I was born in California and raised in Hong Ko...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  67%                 t
# 1               100%                  98%                 f
# 2               100%                  98%                 f
# 3                 0%                  NaN                 f
# 4               100%                  98%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/160139/profil...
# 1  https://a0.muscache.com/im/users/304876/profil...
# 2  https://a0.muscache.com/im/users/304876/profil...
# 3  https://a0.muscache.com/im/users/544166/profil...
# 4  https://a0.muscache.com/im/users/304876/profil...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/160139/profil...         Sheung Wan
# 1  https://a0.muscache.com/im/users/304876/profil...         Sheung Wan
# 2  https://a0.muscache.com/im/users/304876/profil...         Sheung Wan
# 3  https://a0.muscache.com/im/users/544166/profil...         Mid-Levels
# 4  https://a0.muscache.com/im/users/304876/profil...         Sheung Wan
#
#    host_listings_count  host_total_listings_count  \
# 0                    2                          2
# 1                   12                         12
# 2                   12                         12
# 3                    0                          0
# 4                   12                         12
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1  ['email', 'phone', 'reviews', 'jumio', 'selfie...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'selfie...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'selfie...                    t
#
#   host_identity_verified                neighbourhood neighbourhood_cleansed  \
# 0                      t        Sheung Wan, Hong Kong      Central & Western
# 1                      t                          NaN      Central & Western
# 2                      t                          NaN      Central & Western
# 3                      t                          NaN      Central & Western
# 4                      t  Hong Kong Island, Hong Kong      Central & Western
#
#    neighbourhood_group_cleansed  latitude  longitude     property_type  \
# 0                           NaN  22.28352  114.15018  Entire apartment
# 1                           NaN  22.28398  114.14839  Entire apartment
# 2                           NaN  22.28407  114.15570  Entire apartment
# 3                           NaN  22.28222  114.14834  Entire apartment
# 4                           NaN  22.28868  114.14494  Entire apartment
#
#          room_type  accommodates  bathrooms bathrooms_text  bedrooms  beds  \
# 0  Entire home/apt             3        NaN         1 bath       1.0   2.0
# 1  Entire home/apt             3        NaN         1 bath       NaN   2.0
# 2  Entire home/apt             6        NaN         1 bath       2.0   3.0
# 3  Entire home/apt             2        NaN      1.5 baths       1.0   1.0
# 4  Entire home/apt             6        NaN         1 bath       2.0   3.0
#
#                                            amenities      price  \
# 0  ["Essentials", "Heating", "Air conditioning", ...  $1,391.00
# 1  ["Wifi", "Heating", "Cable TV", "Air condition...    $403.00
# 2  ["Essentials", "Wifi", "Heating", "Cable TV", ...  $1,244.00
# 3  ["Wifi", "Cable TV", "Air conditioning", "Kitc...  $2,650.00
# 4  ["Essentials", "Wifi", "Heating", "Cable TV", ...  $1,454.00
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3             365                       3
# 1              14             365                      14
# 2               2             365                       2
# 3               1             365                       1
# 4               2             365                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       4                     365                     365
# 1                      14                     365                     365
# 2                       2                     365                     365
# 3                       1                     365                     365
# 4                       2                     365                     365
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                     3.1                   365.0               NaN
# 1                    14.0                   365.0               NaN
# 2                     2.0                   365.0               NaN
# 3                     1.0                   365.0               NaN
# 4                     2.0                   365.0               NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               22               52               82
# 1                t                0                0                0
# 2                t               30               60               90
# 3                t               30               60               90
# 4                t                0                0                0
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               172            2020-12-23                134
# 1                 0            2020-12-22                229
# 2               365            2020-12-22                272
# 3               365            2020-12-22                 14
# 4                 0            2020-12-23                210
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                      1                       0   2011-02-14  2020-03-24
# 1                      1                       0   2011-03-05  2020-04-18
# 2                      4                       0   2011-06-19  2020-07-07
# 3                      0                       0   2011-07-18  2012-02-06
# 4                     28                       0   2015-05-01  2020-10-10
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  97.0                    10.0                        9.0
# 1                  89.0                     8.0                        9.0
# 2                  89.0                     9.0                        9.0
# 3                  93.0                     9.0                       10.0
# 4                  93.0                    10.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                    9.0                          9.0                    10.0
# 2                   10.0                         10.0                    10.0
# 3                   10.0                         10.0                    10.0
# 4                   10.0                         10.0                    10.0
#
#    review_scores_value  license instant_bookable  \
# 0                  9.0      NaN                f
# 1                  9.0      NaN                f
# 2                  9.0      NaN                f
# 3                  9.0      NaN                f
# 4                 10.0      NaN                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                              14
# 2                              14
# 3                               1
# 4                              14
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                           10
# 2                                           10
# 3                                            1
# 4                                           10
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             4
# 2                                             4
# 3                                             0
# 4                                             4
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.12
# 1                                            0               1.92
# 2                                            0               2.35
# 3                                            0               0.12
# 4                                            0               3.05

# %%
# check datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7047 entries, 0 to 7046
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7047 non-null   int64
#  1   listing_url                                   7047 non-null   object
#  2   scrape_id                                     7047 non-null   int64
#  3   last_scraped                                  7047 non-null   object
#  4   name                                          7046 non-null   object
#  5   description                                   6666 non-null   object
#  6   neighborhood_overview                         3128 non-null   object
#  7   picture_url                                   7047 non-null   object
#  8   host_id                                       7047 non-null   int64
#  9   host_url                                      7047 non-null   object
#  10  host_name                                     7047 non-null   object
#  11  host_since                                    7047 non-null   object
#  12  host_location                                 7031 non-null   object
#  13  host_about                                    4549 non-null   object
#  14  host_response_time                            6028 non-null   object
#  15  host_response_rate                            6028 non-null   object
#  16  host_acceptance_rate                          5482 non-null   object
#  17  host_is_superhost                             7047 non-null   object
#  18  host_thumbnail_url                            7047 non-null   object
#  19  host_picture_url                              7047 non-null   object
#  20  host_neighbourhood                            5852 non-null   object
#  21  host_listings_count                           7047 non-null   int64
#  22  host_total_listings_count                     7047 non-null   int64
#  23  host_verifications                            7047 non-null   object
#  24  host_has_profile_pic                          7047 non-null   object
#  25  host_identity_verified                        7047 non-null   object
#  26  neighbourhood                                 3128 non-null   object
#  27  neighbourhood_cleansed                        7047 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      7047 non-null   float64
#  30  longitude                                     7047 non-null   float64
#  31  property_type                                 7047 non-null   object
#  32  room_type                                     7047 non-null   object
#  33  accommodates                                  7047 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                7026 non-null   object
#  36  bedrooms                                      5787 non-null   float64
#  37  beds                                          6890 non-null   float64
#  38  amenities                                     7047 non-null   object
#  39  price                                         7047 non-null   object
#  40  minimum_nights                                7047 non-null   int64
#  41  maximum_nights                                7047 non-null   int64
#  42  minimum_minimum_nights                        7047 non-null   int64
#  43  maximum_minimum_nights                        7047 non-null   int64
#  44  minimum_maximum_nights                        7047 non-null   int64
#  45  maximum_maximum_nights                        7047 non-null   int64
#  46  minimum_nights_avg_ntm                        7047 non-null   float64
#  47  maximum_nights_avg_ntm                        7047 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              7047 non-null   object
#  50  availability_30                               7047 non-null   int64
#  51  availability_60                               7047 non-null   int64
#  52  availability_90                               7047 non-null   int64
#  53  availability_365                              7047 non-null   int64
#  54  calendar_last_scraped                         7047 non-null   object
#  55  number_of_reviews                             7047 non-null   int64
#  56  number_of_reviews_ltm                         7047 non-null   int64
#  57  number_of_reviews_l30d                        7047 non-null   int64
#  58  first_review                                  3796 non-null   object
#  59  last_review                                   3796 non-null   object
#  60  review_scores_rating                          3704 non-null   float64
#  61  review_scores_accuracy                        3704 non-null   float64
#  62  review_scores_cleanliness                     3704 non-null   float64
#  63  review_scores_checkin                         3704 non-null   float64
#  64  review_scores_communication                   3704 non-null   float64
#  65  review_scores_location                        3705 non-null   float64
#  66  review_scores_value                           3705 non-null   float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              7047 non-null   object
#  69  calculated_host_listings_count                7047 non-null   int64
#  70  calculated_host_listings_count_entire_homes   7047 non-null   int64
#  71  calculated_host_listings_count_private_rooms  7047 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   7047 non-null   int64
#  73  reviews_per_month                             3796 non-null   float64
# dtypes: float64(18), int64(23), object(33)
# memory usage: 4.0+ MB

# %%
# check total number of records and columns
df.shape
# Out:
# (7047, 74)

# %%
# column feature names
df.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'number_of_reviews_l30d',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'license',
#  'instant_bookable',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
# sample record
print(df.iloc[0])
# Out:
# id                                                                                          69074
# listing_url                                                    https://www.airbnb.com/rooms/69074
# scrape_id                                                                          20201222152003
# last_scraped                                                                           2020-12-23
# name                                              Beautiful oasis of plants & art @ best location
# description                                     An ideal Hong location any visitor--hip withou...
# neighborhood_overview                           In the upper part of trendy, hip Sheung Wan, w...
# picture_url                                     https://a0.muscache.com/pictures/84364564/1e0c...
# host_id                                                                                    160139
# host_url                                                 https://www.airbnb.com/users/show/160139
# host_name                                                                                     Amy
# host_since                                                                             2010-07-07
# host_location                                                                           Hong Kong
# host_about                                      I've been with AirBnB now for many years, ofte...
# host_response_time                                                                   within a day
# host_response_rate                                                                           100%
# host_acceptance_rate                                                                          67%
# host_is_superhost                                                                               t
# host_thumbnail_url                              https://a0.muscache.com/im/users/160139/profil...
# host_picture_url                                https://a0.muscache.com/im/users/160139/profil...
# host_neighbourhood                                                                     Sheung Wan
# host_listings_count                                                                             2
# host_total_listings_count                                                                       2
# host_verifications                              ['email', 'phone', 'reviews', 'jumio', 'offlin...
# host_has_profile_pic                                                                            t
# host_identity_verified                                                                          t
# neighbourhood                                                               Sheung Wan, Hong Kong
# neighbourhood_cleansed                                                          Central & Western
# neighbourhood_group_cleansed                                                                  NaN
# latitude                                                                                  22.2835
# longitude                                                                                  114.15
# property_type                                                                    Entire apartment
# room_type                                                                         Entire home/apt
# accommodates                                                                                    3
# bathrooms                                                                                     NaN
# bathrooms_text                                                                             1 bath
# bedrooms                                                                                        1
# beds                                                                                            2
# amenities                                       ["Essentials", "Heating", "Air conditioning", ...
# price                                                                                   $1,391.00
# minimum_nights                                                                                  3
# maximum_nights                                                                                365
# minimum_minimum_nights                                                                          3
# maximum_minimum_nights                                                                          4
# minimum_maximum_nights                                                                        365
# maximum_maximum_nights                                                                        365
# minimum_nights_avg_ntm                                                                        3.1
# maximum_nights_avg_ntm                                                                        365
# calendar_updated                                                                              NaN
# has_availability                                                                                t
# availability_30                                                                                22
# availability_60                                                                                52
# availability_90                                                                                82
# availability_365                                                                              172
# calendar_last_scraped                                                                  2020-12-23
# number_of_reviews                                                                             134
# number_of_reviews_ltm                                                                           1
# number_of_reviews_l30d                                                                          0
# first_review                                                                           2011-02-14
# last_review                                                                            2020-03-24
# review_scores_rating                                                                           97
# review_scores_accuracy                                                                         10
# review_scores_cleanliness                                                                       9
# review_scores_checkin                                                                          10
# review_scores_communication                                                                    10
# review_scores_location                                                                         10
# review_scores_value                                                                             9
# license                                                                                       NaN
# instant_bookable                                                                                f
# calculated_host_listings_count                                                                  1
# calculated_host_listings_count_entire_homes                                                     1
# calculated_host_listings_count_private_rooms                                                    0
# calculated_host_listings_count_shared_rooms                                                     0
# reviews_per_month                                                                            1.12
# Name: 0, dtype: object

# %%
df.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               1
# description                                      381
# neighborhood_overview                           3919
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                     16
# host_about                                      2498
# host_response_time                              1019
# host_response_rate                              1019
# host_acceptance_rate                            1565
# host_is_superhost                                  0
# host_thumbnail_url                                 0
# host_picture_url                                   0
# host_neighbourhood                              1195
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# host_has_profile_pic                               0
# host_identity_verified                             0
# neighbourhood                                   3919
# neighbourhood_cleansed                             0
# neighbourhood_group_cleansed                    7047
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                       7047
# bathrooms_text                                    21
# bedrooms                                        1260
# beds                                             157
# amenities                                          0
# price                                              0
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             0
# maximum_minimum_nights                             0
# minimum_maximum_nights                             0
# maximum_maximum_nights                             0
# minimum_nights_avg_ntm                             0
# maximum_nights_avg_ntm                             0
# calendar_updated                                7047
# has_availability                                   0
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# calendar_last_scraped                              0
# number_of_reviews                                  0
# number_of_reviews_ltm                              0
# number_of_reviews_l30d                             0
# first_review                                    3251
# last_review                                     3251
# review_scores_rating                            3343
# review_scores_accuracy                          3343
# review_scores_cleanliness                       3343
# review_scores_checkin                           3343
# review_scores_communication                     3343
# review_scores_location                          3342
# review_scores_value                             3342
# license                                         7047
# instant_bookable                                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3251
# dtype: int64

# %%
clean_df = df[df.first_review.notnull() & df.last_review.notnull() & df.review_scores_rating.notnull() & df.review_scores_accuracy.notnull() & df.review_scores_accuracy.notnull() & df.review_scores_cleanliness.notnull() & df.review_scores_checkin.notnull() & df.review_scores_communication.notnull() & df.review_scores_location.notnull() & df.review_scores_value.notnull()]

# %%
clean_df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   69074   https://www.airbnb.com/rooms/69074  20201222152003   2020-12-23
# 1   75083   https://www.airbnb.com/rooms/75083  20201222152003   2020-12-22
# 2  103760  https://www.airbnb.com/rooms/103760  20201222152003   2020-12-22
# 3  104626  https://www.airbnb.com/rooms/104626  20201222152003   2020-12-22
# 4  132773  https://www.airbnb.com/rooms/132773  20201222152003   2020-12-23
#
#                                               name  \
# 0  Beautiful oasis of plants & art @ best location
# 1                      SoHo off Hollywood Road  3B
# 2    Central Centre 5 min walk to/from Central MTR
# 3              Entire Flat - Next to Man Mo Temple
# 4                Fabulous 2 Bdrm Aprt Open kitchen
#
#                                          description  \
# 0  An ideal Hong location any visitor--hip withou...
# 1  Located steps from Hollywood road, with new ea...
# 2  Located right in the heart of Central, this 2 ...
# 3  <b>The space</b><br />Situated in one of Hong ...
# 4  Nicely decorated, spacious 2 bedroom apartment...
#
#                                neighborhood_overview  \
# 0  In the upper part of trendy, hip Sheung Wan, w...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The Sheung Wan neighbourhood is ever changing ...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/84364564/1e0c...   160139
# 1  https://a0.muscache.com/pictures/2873745/90c15...   304876
# 2  https://a0.muscache.com/pictures/815221/056993...   304876
# 3  https://a0.muscache.com/pictures/1947265/ef01a...   544166
# 4  https://a0.muscache.com/pictures/36936441/e4c1...   304876
#
#                                    host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/160139       Amy  2010-07-07
# 1  https://www.airbnb.com/users/show/304876     Brend  2010-11-30
# 2  https://www.airbnb.com/users/show/304876     Brend  2010-11-30
# 3  https://www.airbnb.com/users/show/544166    Celine  2011-04-29
# 4  https://www.airbnb.com/users/show/304876     Brend  2010-11-30
#
#                  host_location  \
# 0                    Hong Kong
# 1                    Hong Kong
# 2                    Hong Kong
# 3  Hong Kong Island, Hong Kong
# 4                    Hong Kong
#
#                                           host_about  host_response_time  \
# 0  I've been with AirBnB now for many years, ofte...        within a day
# 1  I was born in California and raised in Hong Ko...  within a few hours
# 2  I was born in California and raised in Hong Ko...  within a few hours
# 3  i am Celine Heuls.\r\ni live in Hong KOng Isla...  a few days or more
# 4  I was born in California and raised in Hong Ko...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  67%                 t
# 1               100%                  98%                 f
# 2               100%                  98%                 f
# 3                 0%                  NaN                 f
# 4               100%                  98%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/160139/profil...
# 1  https://a0.muscache.com/im/users/304876/profil...
# 2  https://a0.muscache.com/im/users/304876/profil...
# 3  https://a0.muscache.com/im/users/544166/profil...
# 4  https://a0.muscache.com/im/users/304876/profil...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/160139/profil...         Sheung Wan
# 1  https://a0.muscache.com/im/users/304876/profil...         Sheung Wan
# 2  https://a0.muscache.com/im/users/304876/profil...         Sheung Wan
# 3  https://a0.muscache.com/im/users/544166/profil...         Mid-Levels
# 4  https://a0.muscache.com/im/users/304876/profil...         Sheung Wan
#
#    host_listings_count  host_total_listings_count  \
# 0                    2                          2
# 1                   12                         12
# 2                   12                         12
# 3                    0                          0
# 4                   12                         12
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1  ['email', 'phone', 'reviews', 'jumio', 'selfie...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'selfie...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'selfie...                    t
#
#   host_identity_verified                neighbourhood neighbourhood_cleansed  \
# 0                      t        Sheung Wan, Hong Kong      Central & Western
# 1                      t                          NaN      Central & Western
# 2                      t                          NaN      Central & Western
# 3                      t                          NaN      Central & Western
# 4                      t  Hong Kong Island, Hong Kong      Central & Western
#
#    neighbourhood_group_cleansed  latitude  longitude     property_type  \
# 0                           NaN  22.28352  114.15018  Entire apartment
# 1                           NaN  22.28398  114.14839  Entire apartment
# 2                           NaN  22.28407  114.15570  Entire apartment
# 3                           NaN  22.28222  114.14834  Entire apartment
# 4                           NaN  22.28868  114.14494  Entire apartment
#
#          room_type  accommodates  bathrooms bathrooms_text  bedrooms  beds  \
# 0  Entire home/apt             3        NaN         1 bath       1.0   2.0
# 1  Entire home/apt             3        NaN         1 bath       NaN   2.0
# 2  Entire home/apt             6        NaN         1 bath       2.0   3.0
# 3  Entire home/apt             2        NaN      1.5 baths       1.0   1.0
# 4  Entire home/apt             6        NaN         1 bath       2.0   3.0
#
#                                            amenities      price  \
# 0  ["Essentials", "Heating", "Air conditioning", ...  $1,391.00
# 1  ["Wifi", "Heating", "Cable TV", "Air condition...    $403.00
# 2  ["Essentials", "Wifi", "Heating", "Cable TV", ...  $1,244.00
# 3  ["Wifi", "Cable TV", "Air conditioning", "Kitc...  $2,650.00
# 4  ["Essentials", "Wifi", "Heating", "Cable TV", ...  $1,454.00
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3             365                       3
# 1              14             365                      14
# 2               2             365                       2
# 3               1             365                       1
# 4               2             365                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       4                     365                     365
# 1                      14                     365                     365
# 2                       2                     365                     365
# 3                       1                     365                     365
# 4                       2                     365                     365
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                     3.1                   365.0               NaN
# 1                    14.0                   365.0               NaN
# 2                     2.0                   365.0               NaN
# 3                     1.0                   365.0               NaN
# 4                     2.0                   365.0               NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               22               52               82
# 1                t                0                0                0
# 2                t               30               60               90
# 3                t               30               60               90
# 4                t                0                0                0
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               172            2020-12-23                134
# 1                 0            2020-12-22                229
# 2               365            2020-12-22                272
# 3               365            2020-12-22                 14
# 4                 0            2020-12-23                210
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                      1                       0   2011-02-14  2020-03-24
# 1                      1                       0   2011-03-05  2020-04-18
# 2                      4                       0   2011-06-19  2020-07-07
# 3                      0                       0   2011-07-18  2012-02-06
# 4                     28                       0   2015-05-01  2020-10-10
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  97.0                    10.0                        9.0
# 1                  89.0                     8.0                        9.0
# 2                  89.0                     9.0                        9.0
# 3                  93.0                     9.0                       10.0
# 4                  93.0                    10.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                    9.0                          9.0                    10.0
# 2                   10.0                         10.0                    10.0
# 3                   10.0                         10.0                    10.0
# 4                   10.0                         10.0                    10.0
#
#    review_scores_value  license instant_bookable  \
# 0                  9.0      NaN                f
# 1                  9.0      NaN                f
# 2                  9.0      NaN                f
# 3                  9.0      NaN                f
# 4                 10.0      NaN                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                              14
# 2                              14
# 3                               1
# 4                              14
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                           10
# 2                                           10
# 3                                            1
# 4                                           10
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             4
# 2                                             4
# 3                                             0
# 4                                             4
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.12
# 1                                            0               1.92
# 2                                            0               2.35
# 3                                            0               0.12
# 4                                            0               3.05

# %%
clean_df.shape
# Out:
# (3701, 74)

# %%
clean_df.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               1
# description                                      115
# neighborhood_overview                           1670
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                     11
# host_about                                      1289
# host_response_time                               490
# host_response_rate                               490
# host_acceptance_rate                             780
# host_is_superhost                                  0
# host_thumbnail_url                                 0
# host_picture_url                                   0
# host_neighbourhood                               744
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# host_has_profile_pic                               0
# host_identity_verified                             0
# neighbourhood                                   1670
# neighbourhood_cleansed                             0
# neighbourhood_group_cleansed                    3701
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                       3701
# bathrooms_text                                     5
# bedrooms                                         591
# beds                                              18
# amenities                                          0
# price                                              0
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             0
# maximum_minimum_nights                             0
# minimum_maximum_nights                             0
# maximum_maximum_nights                             0
# minimum_nights_avg_ntm                             0
# maximum_nights_avg_ntm                             0
# calendar_updated                                3701
# has_availability                                   0
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# calendar_last_scraped                              0
# number_of_reviews                                  0
# number_of_reviews_ltm                              0
# number_of_reviews_l30d                             0
# first_review                                       0
# last_review                                        0
# review_scores_rating                               0
# review_scores_accuracy                             0
# review_scores_cleanliness                          0
# review_scores_checkin                              0
# review_scores_communication                        0
# review_scores_location                             0
# review_scores_value                                0
# license                                         3701
# instant_bookable                                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                                  0
# dtype: int64

# %%
clean_df.drop(['bathrooms', 'neighbourhood_group_cleansed', 'calendar_updated', 'license'], axis=1, inplace=True)
# Out:
# /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# fill NaN with "" for string values
clean_df[['listing_url', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_url', 'host_name', 
    'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 
    'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_has_profile_pic', 
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 
    'property_type', 'room_type', 'bathrooms_text', 'price', 'first_review', 
    'last_review']] = clean_df[['listing_url', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_url', 
    'host_name', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 
    'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_has_profile_pic', 
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed',  
    'property_type', 'room_type', 'bathrooms_text', 'price', 'first_review', 
 'last_review']].fillna(value=" ")
# Out:
# /Users/nattiya/miniconda3/envs/dl/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# fill NaN with 0.0 for float values
clean_df[['latitude', 'longitude', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 
    'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 
    'reviews_per_month']] = clean_df[['latitude', 'longitude', 'review_scores_rating', 'review_scores_accuracy', 
    'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 
    'review_scores_value', 'reviews_per_month']].fillna(value=0.0)

# %%
# fill NaN with 0 for integer values
clean_df[['minimum_nights', 'maximum_nights', 'maximum_minimum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 
    'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 
    'maximum_nights_avg_ntm', 'bedrooms', 'beds']] = clean_df[['minimum_nights', 'maximum_nights', 'maximum_minimum_nights', 
    'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 
    'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'bedrooms', 'beds']].fillna(value=0)

# %%
clean_df.to_csv('../data/Airbnb/Hong_Kong/clean_listings.csv', index=False)
